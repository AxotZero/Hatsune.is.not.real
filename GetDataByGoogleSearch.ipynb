# %%
from selenium import webdriver 
from selenium.webdriver.chrome.options import Options
import time  
import urllib.request
from bs4 import BeautifulSoup as bs
import re  
import os  
#****************************************************
base_url_part1 = 'https://www.google.com/search?q='
base_url_part2 = '&source=lnms&tbm=isch' # base_url_part1以及base_url_part2都是固定不变的，无需更改
search_query = '證件照' # 检索的关键词，可自己输入你想检索的关键字
location_driver = 'D:\Course_2-2\python\isThatReal\chromedriver.exe' # Chrome驱动程序在电脑中的位置
 
class Crawler:
    def __init__(self):
        self.url = base_url_part1 + search_query + base_url_part2
 
    # 启动Chrome浏览器驱动
    def start_brower(self):
        chrome_options = Options()
        chrome_options.add_argument("--disable-infobars")
        # 启动Chrome浏览器  
        driver = webdriver.Chrome(executable_path=location_driver, options=chrome_options)  
        # 最大化窗口，因为每一次爬取只能看到视窗内的图片
        driver.maximize_window()  
        # 浏览器打开爬取页面  
        driver.get(self.url)  
        return driver
 
    def downloadImg(self, driver):  
        t = time.localtime(time.time())
#         foldername = str(t.__getattribute__("tm_year")) + "-" + str(t.__getattribute__("tm_mon")) + "-" + \
#                      str(t.__getattribute__("tm_mday")) # 定义文件夹的名字
        picpath = 'D:/Course_2-2/python/isThatReal/real' # 下载到的本地目录 
        # 路径不存在时创建一个
        if not os.path.exists(picpath): os.makedirs(picpath)
        # 下载图片的本地路径 /home/LQ/ImageDownload/xxx
 
        # 记录下载过的图片地址，避免重复下载  
        img_url_dic = {} 
        x = 1224  
        # 当鼠标的位置小于最后的鼠标位置时,循环执行
        pos = 0     
        for i in range(10): # 此处可自己设置爬取范围
            pos = i * 500 # 每次下滚500  
            js = "document.documentElement.scrollTop=%d" %pos     
            driver.execute_script(js)  
            time.sleep(4)
            # 获取页面源码
            html_page = driver.page_source
            # 利用Beautifulsoup4创建soup对象并进行页面解析
            soup = bs(html_page, "html.parser")
            # 通过soup对象中的findAll函数图像信息提取
            imglist = soup.findAll('img', {'class':'rg_ic rg_i'})
 
            # ??这段代码问题?
            for imgurl in imglist:
                try:
                    if imgurl['src'] not in img_url_dic:
                        print(x, end=' ')
                        target = '{}/{}.jpg'.format(picpath, x)
                        # print ('Downloading image to location: ' + target + '\nurl=' + imgurl['src'])
                        img_url_dic[imgurl['src']] = '' 
                        urllib.request.urlretrieve(imgurl['src'], target)
                        time.sleep(0.3)
                        x += 1  
                except KeyError:
                    print("ERROR!")
                    pass
                    
                    #continue
 
    def run(self):
        print('\t\t\t**************************************\n\t\t\t**\t\tWelcome to Use Spider\t\t**\n\t\t\t**************************************')  
        driver=self.start_brower()
        self.downloadImg(driver)
        driver.close()
        print("Download has finished.")
 
 
if __name__ == '__main__':  
    craw = Crawler() 
    craw.run()
# Out:
# 			**************************************
# 			**		Welcome to Use Spider		**
# 			**************************************
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# 1224 1225 1226 1227 1228 1229 1230 1231 1232 1233 1234 1235 1236 1237 1238 1239 1240 1241 1242 1243 1244 1245 1246 1247 1248 1249 1250 1251 1252 1253 1254 1255 1256 1257 1258 1259 ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# 1260 1261 1262 1263 1264 1265 1266 1267 1268 1269 1270 1271 1272 1273 1274 1275 ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# 1276 1277 1278 1279 1280 1281 1282 1283 1284 1285 1286 1287 1288 1289 1290 1291 ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# 1292 1293 1294 1295 1296 1297 1298 1299 1300 1301 1302 1303 1304 1305 1306 1307 1308 ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# ERROR!
# 1309 1310 1311 1312 1313 1314 1315 1316 1317 1318 1319
